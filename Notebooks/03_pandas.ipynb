# %% [markdown]
# # PANDAS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Définir un objet Series comprenant la population de 4 pays puis afficher les pays ayant une population > 50’000’000.

# %%
ser_pop=pd.Series([70,8,300,1300],index=["France","Suisse","USA","Chine"])
ser_pop
# Out:
# France      70
# Suisse       8
# USA        300
# Chine     1300
# dtype: int64

# %%
ser_pop[0]==ser_pop["France"]
# Out:
# True

# %%
ser_pop[ser_pop>50]
# Out:
# France      70
# USA        300
# Chine     1300
# dtype: int64

# %%
# | = ou  & = et
ser_pop[(ser_pop<10)|(ser_pop>400)]
# Out:
# Suisse       8
# Chine     1300
# dtype: int64

# %% [markdown]
# Définir les noms de l’objet et de la colonne des pays pour la Series précédente

# %%
ser_pop.name="Population"
ser_pop.index.name="Pays"
ser_pop
# Out:
# Pays
# France      70
# Suisse       8
# USA        300
# Chine     1300
# Name: Population, dtype: int64

# %% [markdown]
# Créez un objet Series et ajoutez des dates partant du 3 octobre 2017 par jour jusqu’à aujourd’hui.

# %%
#générer des dates depuis le 3 octobre 2017
dates=pd.date_range("2017-10-03",pd.datetime.today(),freq="d")
#générer des données et un objet Series
ser_date=pd.Series(np.random.randn(len(dates)),index=dates)

# %%
# %matplotlib inline

# %%
#afficher le graphique
ser_date.plot()

# %% [markdown]
# Créez un objet Series avec des résultats par trimestres à partir de 2012.

# %%
trim = pd.period_range("2012-01-01",pd.datetime.today(),freq="Q")
print(trim)
# Out:
# PeriodIndex(['2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2',
#              '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3', '2014Q4',
#              '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1', '2016Q2',
#              '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3', '2017Q4',
#              '2018Q1', '2018Q2', '2018Q3'],
#             dtype='period[Q-DEC]', freq='Q-DEC')

# %%
pd.Series(np.random.random(trim.shape[0])*10000,index=trim).plot()

# %% [markdown]
# Récupérez les données de Wikipédia sur les résultats de NBA et obtenir les statistiques descriptives pour les variables quantitatives.
# On utilisera plutôt Chrome ou Firefox pour ce type de tâches (éviter IE)

# %%
import webbrowser
url='https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records'
webbrowser.open(url)
# Out:
# True

# %%
# on copie le tableau de données et on utilise :
frame_nba=pd.read_clipboard()
# Out:
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\pandas\io\clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)

# %% [markdown]
# Trier les données NBA en fonction de la variable Pct.

# %%
frame_nba.sort_values("Pct.")
# Out:
#     Rank                    Team    Won   Lost   Pct. First NBA season  \
# 29    30  Minnesota Timberwolves    925  1,405  0.397          1989–90
# 28    29    Los Angeles Clippers  1,562  2,326  0.402          1970–71
# 27    28       Memphis Grizzlies    759  1,079  0.413          1995–96
# 26    27           Brooklyn Nets  1,408  1,988  0.415          1976–77
# 25    26       Charlotte Hornets    988  1,260  0.440       1988–89[c]
# 24    25      Washington Wizards  2,096  2,519  0.454          1961–62
# 23    24        Sacramento Kings  2,523  3,010  0.456          1948–49
# 22    23         Toronto Raptors    844    994  0.459          1995–96
# 21    22     Cleveland Cavaliers  1,829  2,059  0.470          1970–71
# 20    21    New Orleans Pelicans    610    686  0.471       2002–03[c]
# 19    20           Orlando Magic  1,116  1,214  0.479          1989–90
# 18    19   Golden State Warriors  2,715  2,923  0.482          1946–47
# ...

# %% [markdown]
# Nettoyage des données

# %%
frame_nba["first season"]=frame_nba["First NBA season"].str[:4]
for col in frame_nba.columns:
    if frame_nba[col].dtype == object:
        frame_nba[col]=pd.to_numeric(frame_nba[col].str.replace(",",""),
                                     errors="ignore")

# %%
frame_nba.head()
# Out:
#    Rank                   Team   Won  Lost   Pct. First NBA season  \
# 0     1      San Antonio Spurs  2114  1282  0.622          1976–77
# 1     2     Los Angeles Lakers  3296  2237  0.596          1948–49
# 2     3         Boston Celtics  3329  2313  0.590          1946–47
# 3     4  Oklahoma City Thunder  2234  1900  0.540          1967–68
# 4     5              Utah Jazz  1914  1646  0.538          1974–75
#
#    Total games   Division  first season
# 0         3396  Southwest          1976
# 1         5533    Pacific          1948
# 2         5642   Atlantic          1946
# 3         4134  Northwest          1967
# 4         3560  Northwest          1974

# %%
frame_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
# Rank                30 non-null int64
# Team                30 non-null object
# Won                 30 non-null int64
# Lost                30 non-null int64
# Pct.                30 non-null float64
# First NBA season    30 non-null object
# Total games         30 non-null int64
# Division            30 non-null object
# first season        30 non-null int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 2.2+ KB

# %%
nba_desc=frame_nba.describe()

# %%
nba_desc
# Out:
#             Rank          Won         Lost       Pct.  Total games  \
# count  30.000000    30.000000    30.000000  30.000000    30.000000
# mean   15.500000  1934.966667  1925.833333   0.494767  3860.800000
# std     8.803408   738.977461   632.989899   0.054404  1309.153541
# min     1.000000   610.000000   686.000000   0.397000  1296.000000
# 25%     8.250000  1440.750000  1436.000000   0.461750  3149.750000
# 50%    15.500000  2075.000000  1931.000000   0.493500  3888.000000
# 75%    22.750000  2450.750000  2322.750000   0.523750  5254.750000
# max    30.000000  3329.000000  3010.000000   0.622000  5642.000000
#
#        first season
# count     30.000000
# mean    1969.700000
# std       16.698441
# min     1946.000000
# 25%     1952.000000
# 50%     1970.000000
# 75%     1979.000000
# max     2002.000000

# %%
# on affiche les équipes ayant gagné plus de 2500 matchs
frame_nba[frame_nba["Won"]>2500]
# Out:
#     Rank                   Team   Won  Lost   Pct. First NBA season  \
# 1      2     Los Angeles Lakers  3296  2237  0.596          1948–49
# 2      3         Boston Celtics  3329  2313  0.590          1946–47
# 10    11     Philadelphia 76ers  2806  2662  0.513          1949–50
# 14    15          Atlanta Hawks  2717  2753  0.497          1949–50
# 15    16        New York Knicks  2761  2878  0.490          1946–47
# 16    17        Detroit Pistons  2692  2840  0.487          1948–49
# 18    19  Golden State Warriors  2715  2923  0.482          1946–47
# 23    24       Sacramento Kings  2523  3010  0.456          1948–49
#
#     Total games   Division  first season
# 1          5533    Pacific          1948
# 2          5642   Atlantic          1946
# 10         5468   Atlantic          1949
# 14         5470  Southeast          1949
# 15         5639   Atlantic          1946
# 16         5532    Central          1948
# 18         5638    Pacific          1946
# ...

# %% [markdown]
# Importez le fichier airbnb.csv depuis Python

# %%
airbnb=pd.read_csv("https://www.stat4decision.com/airbnb.csv")
# Out:
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (43,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
airbnb.loc[100]
# Out:
# id                                                                           16119727
# listing_url                                     https://www.airbnb.com/rooms/16119727
# scrape_id                                                              20170404145355
# last_scraped                                                               2017-04-06
# name                                                  Une studio 20 mètre PARis 12ème
# summary                             3ème étage avec ascenseur Mateo linge 1 Porte ...
# space                                                                             NaN
# description                         3ème étage avec ascenseur Mateo linge 1 Porte ...
# experiences_offered                                                              none
# neighborhood_overview                                                             NaN
# notes                                                                             NaN
# ...

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56535 entries, 0 to 56534
# Data columns (total 95 columns):
# id                                  56535 non-null int64
# listing_url                         56535 non-null object
# scrape_id                           56535 non-null int64
# last_scraped                        56535 non-null object
# name                                56532 non-null object
# summary                             54371 non-null object
# space                               39142 non-null object
# description                         56528 non-null object
# experiences_offered                 56535 non-null object
# neighborhood_overview               33772 non-null object
# notes                               18011 non-null object
# transit                             36224 non-null object
# access                              28754 non-null object
# interaction                         27063 non-null object
# ...

# %% [markdown]
# Importez un tableau en html depuis la page <br>
# http://www.fdic.gov/bank/individual/failed/banklist.html

# %%
bank=pd.read_html("http://www.fdic.gov/bank/individual/failed/banklist.html")

# %%
frame_bank=bank[0]
frame_bank.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution       Closing Date       Updated Date
# 0                   Royal Savings Bank  December 15, 2017  February 21, 2018
# 1                          Conway Bank   October 13, 2017  February 21, 2018
# 2            United Fidelity Bank, fsb       May 26, 2017      July 26, 2017
# 3  First-Citizens Bank & Trust Company        May 5, 2017     March 22, 2018
# 4                         Whitney Bank     April 28, 2017   December 5, 2017

# %%
nba=pd.read_html("https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records",header="infer")

# %%
nba[1].head()
# Out:
#    Rank                   Team   Won  Lost   Pct. First NBA season  \
# 0     1      San Antonio Spurs  2114  1282  0.622          1976–77
# 1     2     Los Angeles Lakers  3296  2237  0.596          1948–49
# 2     3         Boston Celtics  3329  2313  0.590          1946–47
# 3     4  Oklahoma City Thunder  2234  1900  0.540          1967–68
# 4     5              Utah Jazz  1914  1646  0.538          1974–75
#
#    Total games   Division
# 0         3396  Southwest
# 1         5533    Pacific
# 2         5642   Atlantic
# 3         4134  Northwest
# 4         3560  Northwest

# %% [markdown]
# Importez un fichier Excel depuis python. On utilisera excel-data.xlsx et Presidentielle_2017_Resultats_Communes_Tour_1.xls
#
# On a deux approches :
# - avec pd.read_excel en connaissant la feuille qui nous intéresse
# - avec pd.ExcelFile afin de créer un objet dans lequel on pourra avoir toutes les feuilles

# %%
elections=pd.read_excel("../Data/Presidentielle_2017_Resultats_Communes_Tour_1.xls",
                       sheet_name='Feuil1',usecols="A:E")

# %%
elections_excel=pd.ExcelFile("../Data/Presidentielle_2017_Resultats_Communes_Tour_1.xls")

# %%
elections_excel.sheet_names
# Out:
# ['Feuil1', 'Feuil2', 'Feuil3']

# %%
frame_election=elections_excel.parse(sheet_name='Feuil1',usecols="A:E")

# %% [markdown]
# Importez la base de données SQLite salaries et récupérez la table Salaries dans un DataFrame

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine("sqlite:///../Data/Salaries.sqlite")

# %%
engine.table_names()
# Out:
# ['Salaries']

# %%
frame_salaries=pd.read_sql_query("select * from salaries",engine)

# %%
frame_salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#   BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0  167411           0   400184           567595.43         567595.43  2011
# 1  155966      245132   137811           538909.28         538909.28  2011
# 2  212739      106088  16452.6           335279.91         335279.91  2011
# 3   77916     56120.7   198307           332343.61         332343.61  2011
# 4  134402        9737   182235           326373.19         326373.19  2011
#
#   Notes         Agency Status
# 0        San Francisco
# ...

# %% [markdown]
# Il s'agit des salariés de la ville de San Francisco et de leurs salaires

# %%
frame_salaries["JobTitle"]=frame_salaries["JobTitle"].str.lower()

# %%
frame_salaries["JobTitle"].value_counts()
# Out:
# transit operator                                      9424
# special nurse                                         5791
# registered nurse                                      4955
# custodian                                             3214
# firefighter                                           3153
# recreation leader                                     2663
# deputy sheriff                                        2618
# public svc aide-public works                          2518
# police officer 3                                      2421
# patient care assistant                                1945
# public service trainee                                1656
# attorney (civil/criminal)                             1503
# police officer                                        1476
# porter                                                1465
# general laborer                                       1410
# gardener                                              1187
# ...

# %% [markdown]
# Joindre les deux dataframes de crédits

# %%
frame_credit1=pd.read_excel("../Data/credit2.xlsx")

# %%
frame_credit2=pd.read_table("../Data/credit1.txt")

# %%
# on peut extraire les colonnes communnes avec :
[i for i in frame_credit1.columns if i in frame_credit2.columns]
# Out:
# ['Customer_ID']

# %%
# ou avec :
list(frame_credit1.columns & frame_credit2.columns)
# Out:
# ['Customer_ID']

# %%
frame_global=pd.merge(frame_credit1,frame_credit2,on="Customer_ID",how="inner")

# %% [markdown]
# Créez une variable dans le dataframe des crédits pour les classes d'ages

# %%
pd.cut(frame_global["Age"],5).value_counts()
# Out:
# (24.6, 39.2]     845
# (39.2, 53.8]     722
# (9.927, 24.6]    204
# (53.8, 68.4]     187
# (68.4, 83.0]      42
# Name: Age, dtype: int64

# %%
frame_global["Age_disc"]=pd.qcut(frame_global["Age"],4,labels=["a","b","c","d"])

# %%
frame_global["Age_disc"].value_counts()
# Out:
# b    544
# a    505
# d    496
# c    455
# Name: Age_disc, dtype: int64

# %% [markdown]
# ## GROUPBY

# %% [markdown]
# - Données sur les salaires
#
# - On utilise le groupby() pour rassembler les types d’emploi
#
# - Et on calcule des statistiques pour chaque type
#
# On peut utiliser la fonction .agg() avec par exemple ‘mean’ comme paramètre
#
# On utilise aussi fréquemment la fonction apply() combinée à une fonction lambda

# %%
frame_salaries.groupby("JobTitle")["TotalPay"].mean().sort_values(ascending=False)
# Out:
# JobTitle
# general manager-metropolitan transit authority        399211.275000
# chief investment officer                              339653.700000
# chief, fire department                                325971.683333
# chief of police                                       313885.882500
# deputy director of investments                        307899.460000
# chief of department, (fire department)                302377.730000
# gen mgr, public trnsp dept                            297769.413333
# asst chf of dept (fire dept)                          281763.483889
# deputy chief of department,(fire department)          279359.560000
# dep dir for investments, ret                          278592.545000
# adm, sfgh medical center                              270047.446667
# deputy chief 3                                        268256.512857
# assistant deputy chief 2                              267140.253636
# controller                                            264750.753333
# ...

# %%
frame_salaries.groupby("JobTitle")["TotalPay"].agg(["mean",'count']).sort_values("count",
                                                                                 ascending=False)
# Out:
#                                                              mean  count
# JobTitle
# transit operator                                     63958.939444   9424
# special nurse                                        32717.231561   5791
# registered nurse                                    113466.920872   4955
# custodian                                            45448.577343   3214
# firefighter                                         144222.334675   3153
# recreation leader                                     6482.997086   2663
# deputy sheriff                                      105816.697872   2618
# public svc aide-public works                          8242.309452   2518
# police officer 3                                    134906.890909   2421
# patient care assistant                               47114.088098   1945
# public service trainee                                7958.178798   1656
# attorney (civil/criminal)                           135477.018543   1503
# ...

# %%
frame_salaries.groupby("JobTitle")["TotalPay"].apply(lambda x : x.max()-x.min()).sort_values(
                                                                                 ascending=False)
# Out:
# JobTitle
# captain iii (police department)                       446979.91
# asst med examiner                                     351271.98
# lieutenant, fire suppression                          351198.08
# emt/paramedic/firefighter                             337204.86
# general manager-metropolitan transit authority        336768.31
# electronic maintenance tech                           331779.65
# senior physician specialist                           322582.27
# deputy chief 3                                        322018.53
# battlion chief, fire suppressi                        311433.08
# battalion chief, (fire department)                    308887.68
# deputy sheriff                                        308434.84
# battalion chief, fire suppress                        307346.51
# captain, fire suppression                             305410.42
# transit manager 2                                     298925.33
# ...

# %% [markdown]
# Sur les données AirBnB

# %%
airbnb.groupby(["room_type",'cancellation_policy'])[["availability_30","review_scores_accuracy"]].mean()
# Out:
#                                      availability_30  review_scores_accuracy
# room_type       cancellation_policy
# Entire home/apt flexible                    7.447336                9.479310
#                 moderate                    7.198674                9.554314
#                 strict                      8.330799                9.468671
#                 super_strict_30            17.714286                9.250000
#                 super_strict_60            18.636364               10.000000
# Private room    flexible                   10.486439                9.395561
#                 moderate                   10.319897                9.506901
#                 strict                     12.113695                9.406472
# Shared room     flexible                   14.640152                9.350365
#                 moderate                   13.548611                9.267241
#                 strict                     16.059524                9.118056

# %%
airbnb.groupby(["room_type",'cancellation_policy'])[["availability_30",
                                                     "review_scores_accuracy"]].last()
# Out:
#                                      availability_30  review_scores_accuracy
# room_type       cancellation_policy
# Entire home/apt flexible                          19                    10.0
#                 moderate                           4                    10.0
#                 strict                             7                    10.0
#                 super_strict_30                   26                     9.0
#                 super_strict_60                   29                    10.0
# Private room    flexible                          27                    10.0
#                 moderate                          12                    10.0
#                 strict                             0                    10.0
# Shared room     flexible                          30                    10.0
#                 moderate                          20                    10.0
#                 strict                             8                     8.0

# %% [markdown]
# Sur les données de salaires, on a deux approches pour appliquer une condition :

# %%
frame_salaries.query("TotalPay>400000 & JobTitle=='captain iii (police department)'")
# Out:
#    Id  EmployeeName                         JobTitle BasePay OvertimePay  \
# 1   2  GARY JIMENEZ  captain iii (police department)  155966      245132
#
#   OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes         Agency  \
# 1   137811           538909.28         538909.28  2011        San Francisco
#
#   Status
# 1

# %%
frame_salaries[(frame_salaries["TotalPay"]>400000) &
               (frame_salaries["JobTitle"]=="captain iii (police department)")]
# Out:
#    Id  EmployeeName                         JobTitle BasePay OvertimePay  \
# 1   2  GARY JIMENEZ  captain iii (police department)  155966      245132
#
#   OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes         Agency  \
# 1   137811           538909.28         538909.28  2011        San Francisco
#
#   Status
# 1
